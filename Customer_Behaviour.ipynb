# %%
# ✅ Import the necessary libraries
import pandas as pd                # For reading and handling data
import seaborn as sns              # For beautiful graphs
import matplotlib.pyplot as plt    # For plotting charts

# ✅ Load the dataset (file must be in same folder)
df = pd.read_csv("Mall_Customers.csv")
print("✅ Dataset Loaded!")

# ✅ Rename columns to make it easier to use
df.columns = ['CustomerID', 'Gender', 'Age', 'AnnualIncome', 'SpendingScore']

# ✅ Show the first 5 rows of the data
print("📊 First 5 rows:")
print(df.head())
# Out:
# ✅ Dataset Loaded!
# 📊 First 5 rows:
#    CustomerID  Gender  Age  AnnualIncome  SpendingScore
# 0           1    Male   19            15             39
# 1           2    Male   21            15             81
# 2           3  Female   20            16              6
# 3           4  Female   23            16             77
# 4           5  Female   31            17             40

# %% [markdown]
# Data summary and shape

# %%
# ✅ Check basic information (types, nulls)
print("📦 Dataset Info:")
print(df.info())

# ✅ Summary statistics (mean, min, max, etc.)
print("\n📈 Summary Stats:")
print(df.describe())
# Out:
# 📦 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     200 non-null    int64
#  1   Gender         200 non-null    object
#  2   Age            200 non-null    int64
#  3   AnnualIncome   200 non-null    int64
#  4   SpendingScore  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
#
# 📈 Summary Stats:
#        CustomerID         Age  AnnualIncome  SpendingScore
# count  200.000000  200.000000    200.000000     200.000000
# mean   100.500000   38.850000     60.560000      50.200000
# std     57.879185   13.969007     26.264721      25.823522
# min      1.000000   18.000000     15.000000       1.000000
# 25%     50.750000   28.750000     41.500000      34.750000
# 50%    100.500000   36.000000     61.500000      50.000000
# ...

# %% [markdown]
# Gender Bar Graph

# %%
sns.countplot(x='Gender', data=df)
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# Age Distribution(Histogram)

# %%
sns.histplot(df['Age'], kde=True, bins=10)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# Annual Income distribution

# %%
sns.histplot(df['AnnualIncome'], kde=True, color='green')
plt.title("Annual Income Distribution")
plt.show()

# %% [markdown]
# Spending Score Distribution

# %%
sns.histplot(df['SpendingScore'], kde=True, color='orange')
plt.title("Spending Score Distribution")
plt.show()

# %% [markdown]
# Scatter Plot: Income vs Spending (Colored by Gender)

# %%
sns.scatterplot(x='AnnualIncome', y='SpendingScore', hue='Gender', data=df)
plt.title("Income vs Spending Score by Gender")
plt.show()

# %% [markdown]
# Pairplot – All Numeric Columns Together

# %%
sns.pairplot(df[['Age', 'AnnualIncome', 'SpendingScore']])
plt.suptitle("Pairwise Relationships", y=1.02)
plt.show()

# %% [markdown]
# Violin Plot – Income by Gender

# %%
sns.violinplot(x='Gender', y='AnnualIncome', hue='Gender', data=df, palette="Set2", legend=False)
plt.title("Income by Gender")
plt.show()

# %% [markdown]
# Voilin Plot -spending score

# %%
sns.violinplot(x='Gender', y='SpendingScore', hue='Gender', data=df, palette="Set1", legend=False)
plt.title("Spending Score by Gender")
plt.show()

# %%
print("🎉 Project completed: EDA + Charts using Seaborn!")
# Out:
# 🎉 Project completed: EDA + Charts using Seaborn!
